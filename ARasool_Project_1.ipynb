# %% [markdown]
# **Project 1**
#
# Our goal for this project will be to identify the various factors that may influence admission into graduate school. It contains four variables- admit, gre, gpa, rank.
#
# 'admit' is a binary variable. It indicates whether or not a candidate was admitted admit =1) our not (admit= 0)
# 'gre' is GRE score
# 'gpa' stands for Grade Point Average
# 'rank' is the rank of an applicant's undergraduate alma mater, with 1 being the highest and 4 as the lowest.

# %% [markdown]
# 1. **Create a data dictionary**

# %% [markdown]
# ![Screen%20Shot%202017-07-31%20at%204.05.43%20PM.png](attachment:Screen%20Shot%202017-07-31%20at%204.05.43%20PM.png)
